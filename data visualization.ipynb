# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])

# %%
import pandas as pd

df = pd.read_csv('countries.csv')

print(df.to_string())
# Out:
#                        country  year  population
# 0                  Afghanistan  1952     8425333
# 1                  Afghanistan  1957     9240934
# 2                  Afghanistan  1962    10267083
# 3                  Afghanistan  1967    11537966
# 4                  Afghanistan  1972    13079460
# 5                  Afghanistan  1977    14880372
# 6                  Afghanistan  1982    12881816
# 7                  Afghanistan  1987    13867957
# 8                  Afghanistan  1992    16317921
# 9                  Afghanistan  1997    22227415
# 10                 Afghanistan  2002    25268405
# 11                 Afghanistan  2007    31889923
# 12                     Albania  1952     1282697
# 13                     Albania  1957     1476505
# 14                     Albania  1962     1728137
# 15                     Albania  1967     1984060
# 16                     Albania  1972     2263554
# 17                     Albania  1977     2509048
# ...

# %%
import pandas as pd

df = pd.read_csv('sample_data.csv')

print(df.to_string())
# Out:
#    column_a  column_b  column_c
# 0         1         1        10
# 1         2         4         8
# 2         3         9         6
# 3         4        16         4
# 4         5        25         2

# %%
sample_data.column_b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-b9eb61487797> in <module>
# ----> 1 sample_data.column_b
#
# NameError: name 'sample_data' is not defined

# %%
plt.plot([column_b], [column_c])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-7ed02d7dd507> in <module>
# ----> 1 plt.plot([column_b], [column_c])
#
# NameError: name 'column_b' is not defined

# %%
plt.plot([1, 4, 9, 16 ,25], [10, 8, 6, 4, 2])

# %%
plt.plot([1, 4, 9, 16 ,25], [1, 2, 3, 4, 5])
plt.plot([1, 4, 9, 16 ,25], [10, 8, 6, 4, 2])
plt.plot([1, 2, 3, 4 ,5], [10, 8, 6, 4, 2])

# %%
plt.plot([1, 4, 9, 16 ,25], [10, 8, 6, 4, 2], 'ro')
plt.plot([1, 4, 9, 16 ,25], [1, 2, 3, 4, 5], 'b-')

# %%
plt.plot([1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002, 2007], [8425333, 9240934, 10267083, 11537966, 13079460, 14880372, 12881816, 13867957, 16317921, 22227415, 25268405, 31889923])
plt.xlabel('years')
plt.ylabel('population')
plt.title('Afghanistan')
plt.scatter([1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002, 2007], [8425333, 9240934, 10267083, 11537966, 13079460, 14880372, 12881816, 13867957, 16317921, 22227415, 25268405, 31889923])
plt.xlabel('years')
plt.ylabel('population')
plt.title('Afghanistan')
# Out:
# Text(0.5, 1.0, 'Afghanistan')

# %%
plt.plot(kenya.year, kenya.population / 10**6)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-0525ce569f60> in <module>
# ----> 1 plt.plot(kenya.year, kenya.population / 10**6)
#
# NameError: name 'kenya' is not defined
